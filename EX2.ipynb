# %% [markdown]
# # Exercise 2 Tecdhnical Test Tangelo Games

# %%
import random
from random import randint
random.seed(2)

# GET A LIST OF RANDOM NUMBERS
random_numbers = []
for i in range(0,10000):
        random_numbers.append(randint(1, 20))

# %%
random_numbers
# Out:
# [2,
#  3,
#  3,
#  12,
#  6,
#  10,
#  9,
#  20,
#  7,
#  20,
#  2,
#  19,
#  6,
#  14,
#  13,
#  17,
#  12,
#  18,
#  15,
#  17,
#  9,
#  2,
#  1,
#  12,
#  15,
#  11,
#  13,
#  14,
#  17,
#  6,
#  18,
#  6,
#  8,
#  8,
#  1,
#  6,
#  11,
#  6,
#  5,
#  17,
#  17,
#  12,
#  17,
#  18,
#  6,
#  15,
#  14,
#  17,
#  12,
#  19,
#  12,
#  12,
#  15,
#  6,
#  13,
#  15,
#  17,
#  8,
#  16,
#  9,
#  16,
#  17,
#  17,
#  12,
#  15,
#  15,
#  12,
#  19,
#  18,
#  15,
#  16,
#  8,
#  11,
#  6,
#  20,
#  9,
#  16,
#  10,
#  10,
#  17,
#  18,
#  17,
#  17,
#  20,
#  19,
#  14,
#  10,
#  7,
#  16,
#  17,
#  12,
#  20,
#  3,
#  11,
#  1,
#  7,
#  4,
#  2,
#  19,
#  2,
#  9,
#  19,
#  8,
#  4,
#  17,
#  5,
#  9,
#  8,
#  7,
#  2,
#  14,
#  2,
#  2,
#  12,
#  12,
#  6,
#  8,
#  1,
#  3,
#  4,
#  3,
#  1,
#  2,
#  1,
#  12,
#  9,
#  5,
#  6,
#  6,
#  17,
#  1,
#  13,
#  19,
#  2,
#  8,
#  5,
#  2,
#  1,
#  12,
#  20,
#  4,
#  10,
#  11,
#  16,
#  1,
#  10,
#  15,
#  18,
#  20,
#  2,
#  9,
#  13,
# ...

# %%
# FROM THE LIST OF RANDOM NUMBERS GET THE MULTIPLES OF THREEE
random_numbers_3m = []

for x in random_numbers:
    if x % 3 == 0:
        random_numbers_3m.append(x)
        
random_numbers_3m
# Out:
# [3,
#  3,
#  12,
#  6,
#  9,
#  6,
#  12,
#  18,
#  15,
#  9,
#  12,
#  15,
#  6,
#  18,
#  6,
#  6,
#  6,
#  12,
#  18,
#  6,
#  15,
#  12,
#  12,
#  12,
#  15,
#  6,
#  15,
#  9,
#  12,
#  15,
#  15,
#  12,
#  18,
#  15,
#  6,
#  9,
#  18,
#  12,
#  3,
#  9,
#  9,
#  12,
#  12,
#  6,
#  3,
#  3,
#  12,
#  9,
#  6,
#  6,
#  12,
#  15,
#  18,
#  9,
#  3,
#  15,
#  9,
#  9,
#  18,
#  9,
#  6,
#  6,
#  15,
#  15,
#  3,
#  9,
#  3,
#  12,
#  9,
#  9,
#  6,
#  3,
#  6,
#  15,
#  15,
#  18,
#  6,
#  12,
#  12,
#  12,
#  15,
#  15,
#  3,
#  12,
#  3,
#  12,
#  15,
#  12,
#  9,
#  3,
#  12,
#  15,
#  12,
#  9,
#  6,
#  9,
#  18,
#  3,
#  3,
#  12,
#  6,
#  18,
#  3,
#  3,
#  15,
#  6,
#  18,
#  9,
#  6,
#  6,
#  15,
#  12,
#  15,
#  15,
#  6,
#  9,
#  9,
#  12,
#  18,
#  3,
#  18,
#  15,
#  15,
#  6,
#  18,
#  9,
#  9,
#  6,
#  15,
#  3,
#  12,
#  18,
#  3,
#  15,
#  9,
#  15,
#  3,
#  12,
#  6,
#  9,
#  6,
#  15,
#  18,
#  15,
#  12,
#  18,
#  15,
#  18,
#  3,
#  9,
#  3,
#  3,
#  15,
# ...

# %%
random_numbers_3m.count
# Out:
# <function list.count(value, /)>

# %%
#GET THE COUNTS
d = dict((i, random_numbers_3m.count(i)) for i in random_numbers_3m)
d
# Out:
# {3: 495, 12: 495, 6: 457, 9: 524, 18: 496, 15: 504}

# %%
# Get a datafrmae from the dicitonary and sort it

df = pd.DataFrame()
list(d.keys())
list(d.values())

df["number"] = d.keys()
df["count"] = d.values()

df.sort_values("count", ascending = False)
# Out:
#    number  count
# 3       9    524
# 5      15    504
# 4      18    496
# 0       3    495
# 1      12    495
# 2       6    457
